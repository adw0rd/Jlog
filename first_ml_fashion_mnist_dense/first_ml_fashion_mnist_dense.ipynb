# %%
from tensorflow.keras.preprocessing.image import load_img, array_to_img
from tensorflow.keras import utils
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import load_img, array_to_img

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

classes = ['футболка', 'брюки', 'свитер', 'платье', 'пальто', 'туфли', 'рубашка', 'кроссовки', 'сумка', 'ботинки']

def sample(x_train, y_train):
    plt.figure(figsize=(10, 10))
    for i in range(100, 150):
        plt.subplot(5, 10, i - 100 + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(x_train[i], cmap=plt.cm.binary)
        plt.xlabel(classes[y_train[i]])

def what(n):
    print(classes[np.argmax(predictions[n])])
    plt.imshow(x_train[n].reshape(28, 28), cmap=plt.cm.binary)

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# x_train[0].shape
# x_train[0].dtype
sample(x_train, y_train)
x_train = x_train.reshape(60000, 784) / 255
y_train = utils.to_categorical(y_train, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(Dense(800, input_dim=784, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])
print(model.summary())
model.fit(x_train, y_train, batch_size=200, epochs=100, verbose=1)
predictions = model.predict(x_train)
print(np.argmax(predictions[0]))
print(np.argmax(y_train[0]))
model = Sequential()
model.add(Dense(800, input_dim=784, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='SGD', metrics=['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 800)               628000
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                8010
# =================================================================
# Total params: 636,010
# Trainable params: 636,010
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 60000/60000 [==============================] - 2s 30us/sample - loss: 1.1319 - acc: 0.6646
# Epoch 2/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.7229 - acc: 0.7731
# Epoch 3/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.6320 - acc: 0.7990
# Epoch 4/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.5839 - acc: 0.8127
# Epoch 5/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.5524 - acc: 0.8218
# Epoch 6/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.5297 - acc: 0.8262
# Epoch 7/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.5125 - acc: 0.8312
# Epoch 8/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.4987 - acc: 0.8338
# Epoch 9/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4871 - acc: 0.8378
# Epoch 10/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4776 - acc: 0.8400
# Epoch 11/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4688 - acc: 0.8426
# Epoch 12/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4617 - acc: 0.8450
# Epoch 13/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4557 - acc: 0.8461
# Epoch 14/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4493 - acc: 0.8480
# Epoch 15/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4435 - acc: 0.8497
# Epoch 16/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4389 - acc: 0.8511
# Epoch 17/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4347 - acc: 0.8526
# Epoch 18/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4301 - acc: 0.8543
# Epoch 19/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4263 - acc: 0.8552
# Epoch 20/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4225 - acc: 0.8566
# Epoch 21/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4188 - acc: 0.8579
# Epoch 22/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4156 - acc: 0.8586
# Epoch 23/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.4128 - acc: 0.8593
# Epoch 24/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.4093 - acc: 0.8607
# Epoch 25/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.4070 - acc: 0.8615
# Epoch 26/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.4041 - acc: 0.8624
# Epoch 27/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.4011 - acc: 0.8638
# Epoch 28/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3987 - acc: 0.8644
# Epoch 29/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3962 - acc: 0.8646
# Epoch 30/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3940 - acc: 0.8658
# Epoch 31/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3916 - acc: 0.8663
# Epoch 32/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3893 - acc: 0.8684
# Epoch 33/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3872 - acc: 0.8688
# Epoch 34/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3851 - acc: 0.8692
# Epoch 35/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3834 - acc: 0.8692
# Epoch 36/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3807 - acc: 0.8700
# Epoch 37/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3796 - acc: 0.8707
# Epoch 38/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3776 - acc: 0.8716
# Epoch 39/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3758 - acc: 0.8717
# Epoch 40/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3740 - acc: 0.8719
# Epoch 41/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3724 - acc: 0.8723
# Epoch 42/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3709 - acc: 0.8737
# Epoch 43/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3688 - acc: 0.8742
# Epoch 44/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3678 - acc: 0.8741
# Epoch 45/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3659 - acc: 0.8753
# Epoch 46/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3637 - acc: 0.8760
# Epoch 47/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3627 - acc: 0.8754
# Epoch 48/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3611 - acc: 0.8758
# Epoch 49/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3603 - acc: 0.8759
# Epoch 50/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3583 - acc: 0.8771
# Epoch 51/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3573 - acc: 0.8774
# Epoch 52/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3557 - acc: 0.8785
# Epoch 53/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3545 - acc: 0.8780
# Epoch 54/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3529 - acc: 0.8780
# Epoch 55/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3517 - acc: 0.8803
# Epoch 56/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3503 - acc: 0.8796
# Epoch 57/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3494 - acc: 0.8804
# Epoch 58/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3475 - acc: 0.8804
# Epoch 59/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3470 - acc: 0.8809
# Epoch 60/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3451 - acc: 0.8814
# Epoch 61/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3438 - acc: 0.8816
# Epoch 62/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3430 - acc: 0.8821
# Epoch 63/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3418 - acc: 0.8819
# Epoch 64/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3409 - acc: 0.8821
# Epoch 65/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3395 - acc: 0.8829
# Epoch 66/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3385 - acc: 0.8831
# Epoch 67/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3370 - acc: 0.8836
# Epoch 68/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3364 - acc: 0.8838
# Epoch 69/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3352 - acc: 0.8845
# Epoch 70/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3342 - acc: 0.8848
# Epoch 71/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3332 - acc: 0.8854
# Epoch 72/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3321 - acc: 0.8851
# Epoch 73/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3307 - acc: 0.8854
# Epoch 74/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3299 - acc: 0.8861
# Epoch 75/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3286 - acc: 0.8866
# Epoch 76/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3280 - acc: 0.8873
# Epoch 77/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3271 - acc: 0.8867
# Epoch 78/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3260 - acc: 0.8870
# Epoch 79/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3252 - acc: 0.8870
# Epoch 80/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3242 - acc: 0.8874
# Epoch 81/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3234 - acc: 0.8884
# Epoch 82/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3222 - acc: 0.8878
# Epoch 83/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3209 - acc: 0.8888
# Epoch 84/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3204 - acc: 0.8893
# Epoch 85/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3198 - acc: 0.8890
# Epoch 86/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3185 - acc: 0.8891
# Epoch 87/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3176 - acc: 0.8897
# Epoch 88/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.3165 - acc: 0.8895
# Epoch 89/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3160 - acc: 0.8902
# Epoch 90/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3148 - acc: 0.8903
# Epoch 91/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3142 - acc: 0.8913
# Epoch 92/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.3132 - acc: 0.8911
# Epoch 93/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3123 - acc: 0.8913
# Epoch 94/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3114 - acc: 0.8918
# Epoch 95/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3105 - acc: 0.8921
# Epoch 96/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3099 - acc: 0.8924
# Epoch 97/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3085 - acc: 0.8922
# Epoch 98/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3081 - acc: 0.8923
# Epoch 99/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3070 - acc: 0.8936
# Epoch 100/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.3065 - acc: 0.8936
# 9
# 9
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 800)               628000
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                8010
# =================================================================
# Total params: 636,010
# Trainable params: 636,010
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
x_test = x_test.reshape(10000, 784) / 255
y_test = utils.to_categorical(y_test, 10)
scores = model.evaluate(x_test, y_test, verbose=1)
print(scores)
model.save('/tmp/1.h5')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-5-e80b248ea0bf> in <module>()
#       2 x_test = x_test.reshape(10000, 784) / 255
#       3 y_test = utils.to_categorical(y_test, 10)
# ----> 4 scores = model.evaluate(x_test, y_test, verbose=1)
#       5 print(scores)
#       6 model.save('/tmp/1.h5')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     958           verbose=verbose,
#     959           steps=steps,
# --> 960           callbacks=callbacks)
#     961
#     962   def predict(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     361
#     362         # Get outputs.
# --> 363         batch_outs = f(ins_batch)
#     364         if not isinstance(batch_outs, list):
#     365           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: logits and labels must be broadcastable: logits_size=[32,10] labels_size=[320,10]
# 	 [[{{node loss_1/dense_3_loss/softmax_cross_entropy_with_logits}}]]
# 	 [[metrics_2/acc/Identity/_75]]
#   (1) Invalid argument: logits and labels must be broadcastable: logits_size=[32,10] labels_size=[320,10]
# 	 [[{{node loss_1/dense_3_loss/softmax_cross_entropy_with_logits}}]]
# 0 successful operations.
# 0 derived errors ignored.
